# %%
import json

# %%
f = "data/countries.geojson"
with open(f, 'r') as infile:
    g = json.load(infile)

# %%
g.keys()
# Out:
# [u'type', u'features']

# %%
n_features = len(g['features'])
n_features
# Out:
# 255

# %%
polygons = []
multipolygons = []
for i, feature in enumerate(g['features']):
    if feature['geometry']['type'] == 'Polygon':
        n_p = len(feature['geometry']['coordinates'])
        polygons.append((i,n_p))
    elif feature['geometry']['type'] == 'MultiPolygon':
        n_p = len(feature['geometry']['coordinates'])
        multipolygons.append((i,n_p))

# %%
len(polygons)
# Out:
# 105

# %%
len(multipolygons)
# Out:
# 150

# %%
multipolygons[:5]
# Out:
# [(2, 3), (3, 2), (5, 16), (7, 10), (8, 8)]

# %%
len(feature['geometry']['coordinates'][0])
# Out:
# 766

# %%
c = feature['geometry']['coordinates']

# %%
feature.keys()
# Out:
# [u'geometry', u'type', u'properties']

# %%
feature['properties']
# Out:
# {u'ADMIN': u'Zimbabwe', u'ISO_A3': u'ZWE'}

# %%
feature['type']
# Out:
# u'Feature'

# %%
feature['geometry']['type']
# Out:
# u'Polygon'

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/serge/anaconda/envs/gds/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
from shapely.geometry import shape
for feature in g['features']:
    sf = shape(feature['geometry'])
    if feature['geometry']['type'] == 'MultiPolygon':
        for geom in sf.geoms:
            plot(*geom.exterior.xy, color='grey')
    else:
        plot(*sf.exterior.xy, color='grey')

# %%
import pandas as pd

participants = pd.read_csv('data/participants.csv')

# %%
participants
# Out:
#                              name                                 email  \
# 0                     Debra McKay                    dmckay@iastate.edu
# 1                Alain Pholo Bala                       apholo@uj.ac.za
# 2                      Cory Yemen                      yemenc@gmail.com
# 3      Johanna Manrique Hernandez                 jemanriqueh@gmail.com
# 4                   Sudhir Thakur                      thakurs@csus.edu
# 5                    David Patton                     grazi1m@cmich.edu
# 6                    Henry Renski                     hrenski@umass.edu
# 7                    Enza Maltese                 enzamaltese@gmail.com
# 8                        Xian Bak                fangxian8663@gmail.com
# 9                  Cynthia Goytia                      cgoytia@utdt.edu
# 10                    Kenzo Asahi                          kasahi@uc.cl
# 11                Andrea Caragliu                    10268614@polimi.it
# 12              Daniel Broxterman                   dbroxterman@fsu.edu
# 13                Nicholas Garcia        garcia.119@buckeyemail.osu.edu
# 14                  Miriam Valdes            miriam.valdes@uadec.edu.mx
# 15          Hernan Ocampo Solarte                    hocampo@uao.edu.co
# 16                 Andres Vallone          andres.vallone@predoc.uam.es
# 17  Jorge Alberto Orellana Aragón  jorgealbertoorellanaaragon@gmail.com
# 18                Seva Rodnyansky                      rodnyans@usc.edu
#
#          lon      lat
# 0   -93.6465  42.0266
# 1    27.9977 -26.1836
# 2   -74.4471  40.5015
# 3   -74.0721  -4.7110
# 4  -121.4944  38.5816
# 5   -84.7752  43.5912
# 6   -72.4969  42.3404
# 7    13.3614  38.1157
# 8   -88.2073  40.1106
# 9   -96.7970  32.7767
# 10  -70.6693 -33.4489
# 11    9.1859  45.4654
# 12  -84.2807  30.4383
# 13  -82.9988  39.9612
# 14 -101.7068  27.0587
# 15  -76.5358   3.4525
# 16  -70.3975 -23.6509
# 17  -51.2177 -30.0346
# 18 -118.2851  34.0224

# %%
for idx, p in participants.iterrows():
    plot(p['lon'], p['lat'], '^')

# %%
p['lon']
# Out:
# -118.2851

# %%
from shapely.geometry import shape
for feature in g['features']:
    sf = shape(feature['geometry'])
    if feature['geometry']['type'] == 'MultiPolygon':
        for geom in sf.geoms:
            plot(*geom.exterior.xy, color='grey')
    else:
        plot(*sf.exterior.xy, color='grey')
    
for idx, p in participants.iterrows():
    plot(p['lon'], p['lat'], '^')

# %%
minn = (-93.2550, 44.9778)

# %%
import pyproj

# %%
geod = pyproj.Geod(ellps='WGS84')

# %%
gcd = geod.inv(minn[0], minn[1], 27.9977, -26.1836)
gcd
# Out:
# (88.51392675375249, -52.07449614771201, 14439038.301326025)

# %%
gcd[-1] * 0.000621371
# Out:
# 8971.999668333254

# %%
waypoints = geod.npts(minn[0], minn[1], 27.9977, -26.1836, 20)

# %%
waypoints
# Out:
# [(-84.55017113315174, 44.80584990996164),
#  (-75.99367233192807, 43.97922150374636),
#  (-67.75630625215791, 42.53342598534008),
#  (-59.95939730745371, 40.5250588254201),
#  (-52.6670427627056, 38.022665784753144),
#  (-45.892486791627256, 35.098197384876194),
#  (-39.611650300818106, 31.820834657144264),
#  (-33.777369238815254, 28.253526775495367),
#  (-28.3308111896402, 24.451706730804606),
#  (-23.20915404095716, 20.46340997494556),
#  (-18.350010790396198, 16.330137995196903),
#  (-13.693507620172042, 12.08802888018575),
#  (-9.182853111207635, 7.769091214798151),
#  (-4.764014878467847, 3.4023911920384973),
#  (-0.3849059366991696, -0.9848374389291883),
#  (4.005672552069825, -5.366148034129521),
#  (8.459178606624064, -9.714867105484755),
#  (13.028451692931554, -14.003071107776016),
#  (17.768683838023406, -18.200515361975736),
#  (22.738051540211657, -22.273489122646833)]

# %%
route = [minn]
route.extend(waypoints)
route.append((27.9977, -26.1836))

# %%
route = np.array(route)

# %%
plot(route[:,0], route[:,1])

# %%
from shapely.geometry import shape
for feature in g['features']:
    sf = shape(feature['geometry'])
    if feature['geometry']['type'] == 'MultiPolygon':
        for geom in sf.geoms:
            plot(*geom.exterior.xy, color='grey')
    else:
        plot(*sf.exterior.xy, color='grey')
    
for idx, p in participants.iterrows():
    plot(p['lon'], p['lat'], '^')     

plot(route[:,0], route[:,1])

# %% [markdown]
# ## On your own
#
# 1. Calculate and plot the great circle routes bringing our participants to the workshop.

# %%
from shapely.geometry import shape
for feature in g['features']:
    sf = shape(feature['geometry'])
    if feature['geometry']['type'] == 'MultiPolygon':
        for geom in sf.geoms:
            plot(*geom.exterior.xy, color='grey')
    else:
        plot(*sf.exterior.xy, color='grey')
    
for idx, p in participants.iterrows():
    plot(p['lon'], p['lat'], '^')     


for idx, p in participants.iterrows():
    waypoints = geod.npts(minn[0], minn[1], p['lon'], p['lat'], 20)
    route = [minn]
    route.extend(waypoints)
    route.append((p['lon'], p['lat']))
    route = np.array(route)
    plot(route[:,0], route[:,1])
