# %% [markdown]
# # Sequences
#
# ## Standard Types (Primatives)
#
# - numbers
# - strings
# - **lists**
# - **tuples**
# - sets
# - dictionaries

# %% [markdown]
# ## Lists
#
# ### Characteristics
#
# - flexibile containers (strings only contain alphanumeric characters)
# - heterogeneous elements
# - nestable
# - mutable
#
# ### Creation

# %%
x = ['a', 1, 'b', -8, 7.2]
x
# Out:
# ['a', 1, 'b', -8, 7.2]

# %%
z = [x, 'a string of words']
z
# Out:
# [['a', 1, 'b', -8, 7.2], 'a string of words']

# %%
y = []
y
# Out:
# []

# %% [markdown]
# ### Slicing

# %%
x
# Out:
# ['a', 1, 'b', -8, 7.2]

# %%
x[2]
# Out:
# 'b'

# %%
x[1:-1]
# Out:
# [1, 'b', -8]

# %%
x[0]
# Out:
# 'a'

# %%
x[-3:]
# Out:
# ['b', -8, 7.2]

# %% [markdown]
# ### Nestable

# %%
a = range(4)
b = ['every', 'other', 'word']
c = [a, b]
c
# Out:
# [[0, 1, 2, 3], ['every', 'other', 'word']]

# %% [markdown]
# ### Mutable

# %%
c
# Out:
# [[0, 1, 2, 3], ['every', 'other', 'word']]

# %%
c[0] = 'this is a string'
c
# Out:
# ['this is a string', ['every', 'other', 'word']]

# %%
c[0][0]
# Out:
# 't'

# %%
c[0][0] = 'T'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-14f494c89b6c> in <module>()
# ----> 1 c[0][0] = 'T'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# List Operations

# %%
a = ['1', 'serge', 1000]

# %%
b = a + a
b
# Out:
# ['1', 'serge', 1000, '1', 'serge', 1000]

# %%
c = a * 4
c
# Out:
# ['1',
#  'serge',
#  1000,
#  '1',
#  'serge',
#  1000,
#  '1',
#  'serge',
#  1000,
#  '1',
#  'serge',
#  1000]

# %% [markdown]
# List functions

# %%
x = [1, 2, 3, 90]
len(x)
# Out:
# 4

# %%
max(x)
# Out:
# 90

# %%
min(x)
# Out:
# 1

# %% [markdown]
# List methods

# %%
y = []
y
# Out:
# []

# %%
y.append(10)
y
# Out:
# [10]

# %%
x = [1, 2, 3]
x
# Out:
# [1, 2, 3]

# %%
x.append(y)
x
# Out:
# [1, 2, 3, [10]]

# %%
x.extend(y)
x
# Out:
# [1, 2, 3, [10], 10]

# %% [markdown]
# Note the subtle difference between the two methods. Sometimes you will want to use append, and other times extend is what you need.
#
# Other list methods, sort and reverse:

# %%
x = [7, 1, 3, 12]
x
# Out:
# [7, 1, 3, 12]

# %%
x.sort()
x
# Out:
# [1, 3, 7, 12]

# %%
x.reverse()
x
# Out:
# [12, 7, 3, 1]

# %% [markdown]
# Keep in mind that they are in-place methods meaning they modify the object. In other words they don’t return anything, but rather work on the object’s data:

# %%
z = x.sort()

# %%
z

# %%
type(z)
# Out:
# NoneType

# %% [markdown]
# Other useful list methods

# %%
x = [1, 2, 3, 3, 3, 4, 5, 6, 7]
x.count(3)
# Out:
# 3

# %%
x.count(-8)
# Out:
# 0

# %%
3 in x
# Out:
# True

# %%
-8 in x
# Out:
# False

# %%
x.pop()
# Out:
# 7

# %% [markdown]
# Lists as Stacks (LIFO)

# %%
l = range(5)
l
# Out:
# [0, 1, 2, 3, 4]

# %%
l.pop()
# Out:
# 4

# %%
l.pop()
# Out:
# 3

# %%
l.pop()
# Out:
# 2

# %%
l.pop()
# Out:
# 1

# %%
l.pop()
# Out:
# 0

# %%
l.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-9e6f3717293a> in <module>()
# ----> 1 l.pop()
#
# IndexError: pop from empty list

# %% [markdown]
# Lists as Ques (FIFO)

# %%
l = range(5)

# %%
l.pop(0)
# Out:
# 0

# %%
l.pop(0)
# Out:
# 1

# %%
l.pop(0)
# Out:
# 2

# %%
l.pop(0)
# Out:
# 3

# %%
l.pop(0)
# Out:
# 4

# %% [markdown]
# ## Tuples
#
# ### Characteristics
#
# - similar to lists
# - exception = immutable
#
# ### Creating Tuples

# %%
t = (1, 2, 3, 'a', 'b', 'stella')
t
# Out:
# (1, 2, 3, 'a', 'b', 'stella')

# %%
t = 1, 2, 3, 'a', 'b', 'stella'
t
# Out:
# (1, 2, 3, 'a', 'b', 'stella')

# %%
x = 1,

# %%
x
# Out:
# (1,)

# %%
y = 1

# %%
y
# Out:
# 1

# %%
x == y
# Out:
# False

# %% [markdown]
# Tuple Methods

# %%
t = 'a', 'b', 'c'
t
# Out:
# ('a', 'b', 'c')

# %%
t.count('b')
# Out:
# 1

# %%
t.index('b')
# Out:
# 1

# %%
t.index('s')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-03b495d32e98> in <module>()
# ----> 1 t.index('s')
#
# ValueError: tuple.index(x): x not in tuple

# %% [markdown]
# ### Immutability

# %%
t
# Out:
# ('a', 'b', 'c')

# %%
t[0] = 'A'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-d8f50996a189> in <module>()
# ----> 1 t[0] = 'A'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Nestable

# %%
t
# Out:
# ('a', 'b', 'c')

# %%
s = 1, 2, t
s
# Out:
# (1, 2, ('a', 'b', 'c'))

# %% [markdown]
# Note that while the tuple is immutable, if it contains any elements that are mutable we can change the elements of the mutable elements of the tuple.

# %%
s = [1,2,3]
t = 'a', s

# %%
t
# Out:
# ('a', [1, 2, 3])

# %%
t[1][1] = 7

# %%
t
# Out:
# ('a', [1, 7, 3])

# %%
t[0][0]
# Out:
# 'a'

# %%
t[0][0] = 'A'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-8bc12d7fe332> in <module>()
# ----> 1 t[0][0] = 'A'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### Converting between lists and tuples

# %%
t = 'a', 'b', 'c'
t
# Out:
# ('a', 'b', 'c')

# %%
l = list(t)
l
# Out:
# ['a', 'b', 'c']

# %%
tl = tuple(l)
tl
# Out:
# ('a', 'b', 'c')
